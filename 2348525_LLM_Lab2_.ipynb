# %% [markdown]
# <a href="https://colab.research.google.com/github/KiranVarghese25/LLM_LabFIles/blob/main/2348525_LLM_Lab2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dotenv
# !pip install langchain
# !pip install langchain-groq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.6/983.6 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.9/357.9 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.1 MB/s eta 0:00:00
# ...

# %%
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
import os

# %%
load_dotenv()

# Retrieve the API key from the environment variable
api_key = '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'
# Print the API key to ensure it is loaded correctly (for debugging purposes, remove this in production)
print(api_key)
# Out:
# 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

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma-7b-it')

# %%
parser = StrOutputParser()
chain = model | parser
chain.invoke('Explain the big bang theory')
# Out:
# "**Big Bang Theory:**\n\nThe Big Bang theory is the dominant scientific explanation for the origin and evolution of the universe. It suggests that the universe as we know it today arose from a **primordial singularity**, an infinitely dense and hot point of energy that existed approximately **13.8 billion years ago**.\n\n**Key Concepts:**\n\n**1. Primordial Singularity:**\n- A point of infinite density and temperature from which the universe expanded and cooled over time.\n- All the matter and energy in the universe today is believed to have originated from this singularity.\n\n\n**2. Expansion:**\n- The universe is expanding at an accelerating rate.\n- This expansion is supported by observational evidence, such as the cosmic microwave background radiation (CMB).\n\n\n**3. Cooling:**\n- As the universe expanded, it cooled down from its initial high temperature.\n- This cooling allowed for the formation of subatomic particles, atoms, and eventually stars and galaxies.\n\n\n**4. Nucleo
# ...

# %% [markdown]
# Question Answering

# %%
template = (
    """
    you're question answering expert
answer : {answer}
"""
)

# %%
prompt = PromptTemplate.from_template(template=template)

# %%
chain =  prompt | model | parser

# %%
answer = """
tell me about the big bang theory
"""

# %%
result = chain.invoke({'answer':answer})
print(result)
# Out:
# ## The Big Bang Theory:
#
# The Big Bang Theory is the leading scientific explanation for how the universe began. It suggests that the universe as we know it today arose from a **primordial singularity**, a point of infinite density and temperature from which the entire universe expanded and cooled over time.
#
# **Key aspects of the Big Bang Theory:**
#
# **1. Singularity:**
# - The universe began as a singularity, a point of infinite density and temperature, around 13.8 billion years ago.
# - This singularity is thought to be a quantum fluctuation in the fabric of spacetime.
#
#
# **2. Expansion:**
# - From the singularity, the universe rapidly expanded and cooled, forming the fundamental particles and forces.
# - This expansion is still happening today, causing distant objects to move further apart.
#
#
# **3. Nucleosynthesis:**
# ...

# %%
model = ChatGroq(api_key = api_key ,model_name = 'llama3-8b-8192')
parser = StrOutputParser()
chain = model | parser
chain.invoke('Explain the big bang theory')
# Out:
# "The Big Bang Theory! One of the most widely accepted and fascinating theories in the field of cosmology. Here's a simplified explanation:\n\n**What is the Big Bang Theory?**\n\nThe Big Bang Theory proposes that the universe began as an infinitely hot and dense point called a singularity around 13.8 billion years ago. This singularity expanded rapidly, and as it did, it cooled and formed subatomic particles, atoms, and eventually the stars and galaxies we see today.\n\n**Key Evidence Supporting the Big Bang Theory:**\n\n1. **Cosmic Microwave Background Radiation**: In the 1960s, scientists discovered a faint glow of microwave radiation that fills the entire universe, known as the Cosmic Microwave Background Radiation (CMB). This radiation is thought to be the residual heat from the early universe.\n2. **Abundance of Light Elements**: According to the Big Bang Theory, the universe was initially too hot for atoms to exist. As it expanded and cooled, protons, neutrons, and electrons com
# ...

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma2-9b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('Explain the big bang theory')
# Out:
# '## The Big Bang Theory Explained:\n\nThe Big Bang theory is the prevailing cosmological model for the universe. It describes the universe\'s evolution from an extremely hot, dense state to its present form. \n\nHere\'s a breakdown:\n\n**The Beginning:**\n\n* **Singularity:** Around 13.8 billion years ago, the universe began as an incredibly small, hot, and dense point called a singularity.  \n* **Expansion:** This singularity didn\'t explode in the traditional sense, but rather underwent a rapid expansion – the "Big Bang."  \n\n**Early Universe:**\n\n* **Cooling and Inflation:** As the universe expanded, it cooled. During this rapid expansion, known as inflation, the universe grew exponentially in size.\n* **Formation of Fundamental Particles:**  Subatomic particles like quarks and leptons formed from the energy as the universe cooled.\n* **Nucleosynthesis:**  Protons and neutrons combined to form the first atomic nuclei, primarily hydrogen and helium.\n\n**Structure Formation:**\n\
# ...

# %% [markdown]
# From Chatgpt

# %% [markdown]
# ![Screenshot 2024-07-11 105025.png](data:image/png;base64,...)

# %% [markdown]
# From Gemini![Screenshot 2024-07-11 at 11.55.37 AM.png](data:image/png;base64,...)
